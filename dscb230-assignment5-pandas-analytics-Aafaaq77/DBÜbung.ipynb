# %%
import pandas as pd

# %%
df = pd.read_parquet('Iowa_Liquor_Sales2020-21.parquet', engine='fastparquet')

# %%
df.head(4)
# Out:
#   Invoice/Item Number       Date  Store Number                    Store Name  \
# 0     INV-31574300001 2020-11-02          2501             Hy-Vee  #2 / Ames
# 1     INV-28409200221 2020-07-01          2500   Hy-Vee Food Store #1 / Ames
# 2     INV-28435900006 2020-07-02          4129               Cyclone Liquors
# 3     INV-28437200023 2020-07-02          5135  Fareway Stores #155 / Huxley
#
#               Address    City  Zip Code                Store Location  \
# 0      640 Lincolnway    Ames   50010.0                          None
# 1  3800 W Lincoln Way    Ames   50010.0                          None
# 2     626 Lincoln Way    Ames   50010.0  POINT (-93.618911 42.022854)
# 3          911 Hwy 69  Huxley   50124.0                          None
#
#    County Number County  ...  Item Number             Item Description  Pack  \
# 0           85.0  STORY  ...        76430            Oxtails Rum Punch     6
# ...

# %%
df.columns
# Out:
# Index(['Invoice/Item Number', 'Date', 'Store Number', 'Store Name', 'Address',
#        'City', 'Zip Code', 'Store Location', 'County Number', 'County',
#        'Category', 'Category Name', 'Vendor Number', 'Vendor Name',
#        'Item Number', 'Item Description', 'Pack', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)'],
#       dtype='object')

# %%
df.iloc[:2, :10]
# Out:
#   Invoice/Item Number       Date  Store Number                   Store Name  \
# 0     INV-31574300001 2020-11-02          2501            Hy-Vee  #2 / Ames
# 1     INV-28409200221 2020-07-01          2500  Hy-Vee Food Store #1 / Ames
#
#               Address  City  Zip Code Store Location  County Number County
# 0      640 Lincolnway  Ames   50010.0           None           85.0  STORY
# 1  3800 W Lincoln Way  Ames   50010.0           None           85.0  STORY

# %%
df.iloc[:2, 10:20]
# Out:
#     Category   Category Name  Vendor Number                     Vendor Name  \
# 0  1071100.0  Cocktails /RTD          626.0  JDSO INC / Red Boot Distillery
# 1  1022100.0   Mixto Tequila          395.0                         PROXIMO
#
#    Item Number             Item Description  Pack  Bottle Volume (ml)  \
# 0        76430            Oxtails Rum Punch     6                1750
# 1        87410  Jose Cuervo Especial Silver     6                1750
#
#    State Bottle Cost  State Bottle Retail
# 0               5.97                 8.96
# 1              21.00                31.50

# %%
df.iloc[:2, 20:]
# Out:
#    Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)
# 0             6           53.76                  10.5                   2.77
# 1             2           63.00                   3.5                   0.92

# %%
split_position = -5
df['invoice_no'] = df['Invoice/Item Number'].str[:split_position]
df['item_no'] = df['Invoice/Item Number'].str[split_position:]

# %%
df.groupby('invoice_no')['item_no'].count().sort_values(ascending=False)
# Out:
# invoice_no
# INV-363716    512
# INV-324029    333
# INV-272428    320
# INV-259711    283
# INV-326000    272
#              ...
# INV-327733      1
# INV-327731      1
# INV-327327      1
# INV-327293      1
# INV-242906      1
# Name: item_no, Length: 6868, dtype: int64
